# %%
renameLst = [('_BIC_CTRADE_CH', 'CUST_CTRADE_CH'), ('CTRADE_CH_DESC', 'CUST_CTRADE_CH_DESC'), ('_BIC_CSUB_TRAD', 'CUST_CSUB_TRAD'), ('CSUB_TRAD_DESC', 'CUST_CSUB_TRAD_DESC'), 
             ('_BIC_CDMD_AREA', 'CUST_CDMD_AREA'), ('CDMD_AREA_DESC', 'CUST_CDMD_AREA_DESC'), ('POSTAL_CD', 'POSTAL_CODE'), ('_BIC_CSUP_CUST', 'ORDER_BLOCK_ID')]

CUSTOMER_COLUMNS = [
                    'CUSTOMER',
                    'CUST_CTRADE_CH',
                    'CUST_CTRADE_CH_DESC',
                    'CUST_CSUB_TRAD',
                    'CUST_CSUB_TRAD_DESC',
                    'CUST_GRP4',
                    'CUST_GRP4_DESC',
                    'CUST_CDMD_AREA',
                    'CUST_CDMD_AREA_DESC',
                    'CUST_ROUTED',
                    'CUST_CCAF_GROUP',
                    'POSTAL_CODE',
                    'LONGITUDE',
                    'LATITUDE'
                   ]
COUNTRY_INFO = {
               'gr': {"country": "gr", "salesOrgLst": ['1200'], "companyCodelst": ['0450']},
               'ng': {"country": "ng", "salesOrgLst": ['9400'], "companyCodelst": ['0470']},
               'it': {"country": "it", "salesOrgLst": ['6300'], "companyCodelst": ['0594']},
               'ru': {"country": "ru", "salesOrgLst": ['3801', '3802', '3803', '3804', '3805', '3806'], "companyCodelst": ['0403']},
               'ch': {"country": "ch", "salesOrgLst": ['5500'], "companyCodelst": ['0590']},
               'hu': {"country": "hu", "salesOrgLst": ['2800'], "companyCodelst": ['0522']},
               'bg': {"country": "bg", "salesOrgLst": ['4900'], "companyCodelst": ['0428']},
               'ie': {"country": "ie", "salesOrgLst": ['7800', '7900'], "companyCodelst": ['0480', '0491']},
               'ro': {"country": "ro", "salesOrgLst": ['9100'], "companyCodelst": ['0580']},
               'pl': {"country": "pl", "salesOrgLst": ['6100'], "companyCodelst": ['0563']}, 
               'cy': {"country": "cy", "salesOrgLst": ['5100'], "companyCodelst": ['0457']}, 
               'cz': {"country": "cz", "salesOrgLst": ['4500'], "companyCodelst": ['0530']}, 
               'sk': {"country": "sk", "salesOrgLst": ['4090'], "companyCodelst": ['0533']},
               'rs': {"country": "rs", "salesOrgLst": ['2500'], "companyCodelst": ['0440']},
               'me': {"country": "me", "salesOrgLst": ['8200'], "companyCodelst": ['0441']},
               'kv': {"country": "kv", "salesOrgLst": ['9200'], "companyCodelst": ['0443']},
               'ua': {"country": "ua", "salesOrgLst": ['7200'], "companyCodelst": ['0560']}, 
               'md': {"country": "md", "salesOrgLst": ['2000'], "companyCodelst": ['0460']}, 
               'am': {"country": "am", "salesOrgLst": ['9600'], "companyCodelst": ['0410']},  
               'mk': {"country": "mk", "salesOrgLst": ['9500'], "companyCodelst": ['0430']}, 
               'hr': {"country": "hr", "salesOrgLst": ['8100'], "companyCodelst": ['0570']},
               'ba': {"country": "ba", "salesOrgLst": ['8600'], "companyCodelst": ['0573']}, 
               'si': {"country": "si", "salesOrgLst": ['8500'], "companyCodelst": ['0540']},
               'by': {"country": "by", "salesOrgLst": ['2300'], "companyCodelst": ['0550']},
               'lv': {"country": "lv", "salesOrgLst": ['3100'], "companyCodelst": ['0415']}, 
               'lt': {"country": "lt", "salesOrgLst": ['3300'], "companyCodelst": ['0417']},
               'ee': {"country": "ee", "salesOrgLst": ['3200'], "companyCodelst": ['0416']},
               'at': {"country": "at", "salesOrgLst": ['1100'], "companyCodelst": ['0526']}, 
              }



GLOBAL_CUST_HIER2_LIST = ['KA', 'NK']
GLOBAL_ORDER_BLOCK_LIST = ['CW', 'F', 'I', '#', 'C', 'TS', 'PR', 'NR', 'VF']
CUST_TRAD_CHANNEL_NOT_INVOLVED_CODES = ['036','099' ]


COOLER_FILE_PATH = "abfss://cchbc@cchbcaadls2prod.dfs.core.windows.net/sources/ca/cch_bw/mtc/curated/CA_CAM015_CDE_Doors/{CAPS_CC}_CAM015/COMP_CODE={companyCode}/"
SALES_FILE_PATH  = 'abfss://cchbc@cchbcaadls2prod.dfs.core.windows.net/sources/ca/cch_bw/mtc/curated/CA_FSM003_Sales_Direct_Indirect/{CAPS_CC}_FSM003/SALESORG={salesOrg}/'
CUSTOMER_INPUT_FILE_PATH  = "abfss://cchbc@cchbcaadls2prod.dfs.core.windows.net/sources/ca/cch_bw/md/input/CA_0CUS03_Customer/{CAPS_CC}_0CUS03/"
CUSTOMER_RAW_FILE_PATH  = "abfss://cchbc@cchbcaadls2prod.dfs.core.windows.net/sources/ca/cch_bw/md/raw/CA_0CUS03_Customer/{CAPS_CC}_0CUS03/"
DEMOGRAPHICS_FILE_PATH = "adl://cchbcaalabchg0059616dls.azuredatalakestore.net/development/test_taa/{cc}/taa_output_{cc}.csv"
CALENDAR_FILE_PATH = "abfss://cchbc@cchbcaadls2prod.dfs.core.windows.net/sources/ca/cch_bw/md/raw/CA_FACCAL_Calendar/CA_FACCAL/Calendar_CCH.csv"

COOLER_SELECTED_COLUMNS_AND_ALIASES = {
                                        'CUSTOMER':'CUSTOMER',
                                        'EQUIPMENT':'EQUIPEMENT',
                                        'CUSTOMERS_WITH_COOLERS':'CUSTOMERS_WITH_COOLERS',
                                        'DF_STATUS_D':'DF_STATUS_D', 
                                        'ACTUAL_DOORS':'ACTUAL_DOORS'
                                      }
COOLER_FEATURES = ['CUSTOMER', 'EQUIPMENT', 'ACTUAL_DOORS']

INCLUDE_COLS_LIST = ['CUSTOMER','LONGITUDE', 'LATITUDE', 'CUST_CTRADE_CH', 'CUST_CTRADE_CH_DESC','TAA_TC',
                     'CUST_CSUB_TRAD', 'CUST_CSUB_TRAD_DESC', 'CUST_GRP4', 'CUST_GRP4_DESC', 'CUST_CDMD_AREA', 'CUST_CDMD_AREA_DESC', 'CUST_ROUTED', 'CUST_CCAF_GROUP',
                     'POSTAL_CODE', 'urbanicity', 'di_pc_mean', 'wvce_01_pc', 'wvce_02_pc',
                     'WVSEG_A_mean', 'WVSEG_B_mean', 'WVSEG_C_mean', 'WVSEG_D_mean', 'WVSEG_E_mean', 'WVSEG_F_mean', 'WVSEG_G_mean', 'WVSEG_H_mean', 'WVSEG_I_mean', 'WVSEG_J_mean', 'WVSEG_U_mean',
                     'monthly_traffic_avg_mean','Season_traffic_perc_diff', 'Weekend_traffic_perc_diff', 'TF_WINTER', 'TF_SUMMER',
                     'Percentage_monthly_traffic_morning_avg_mean', 'Percentage_monthly_traffic_afternoon_avg_mean', 'Percentage_monthly_traffic_evening_avg_mean', 'Percentage_monthly_traffic_night_avg_mean',
                     'pop_sum', 'hh_sum', 'ta_size', 'di_ci_mean', 'di_mio_sum', 'wvce_01_sum', 'wvce_02_sum' ,'unempl_sum',
                     'population_density', 'competitor_count_density',
                     'Percentage_age_t0014_sum', 'Percentage_age_t1529_sum', 'Percentage_age_t3044_sum', 'Percentage_age_t4559_sum', 'Percentage_age_t60pl_sum',
                     'monthly_proportion_residents_avg_mean', 'monthly_proportion_workers_avg_mean', 'monthly_proportion_others_avg_mean', 'monthly_proportion_same_state_avg_mean', 'monthly_proportion_other_state_avg_mean',
                     'monthly_proportion_unknown_avg_mean', 'commercial_area_poi', 'industrial_area_poi', 'park_area_poi', 'residential_area_poi', 'retail_area_poi', 'pofw_poi',
                     'pofw_christian_poi', 'pofw_muslim_poi', 'parking_poi','transport_poi', 'accomodation_poi', 'catering_poi', 'education_school_poi', 'education_university_poi',
                     'health_poi', 'leasure_poi', 'outdoor_poi', 'public_poi', 'shopping_poi', 'sports_poi', 'tourism_poi',
                     'outlet_count', 'competitor_count','COOLER_DOORS_SUM','COOLER_EQUIP_COUNT','Sales_NSR_imputed','Sales_Volume_in_UC_imputed']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
