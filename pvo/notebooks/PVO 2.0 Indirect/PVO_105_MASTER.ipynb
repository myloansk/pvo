# %%
country = 'at'
env = 'development'
partition_date=datetime.now().strftime("%Y%m%d_%H%M%S")
model = 'rf_' + country + '_' + partition_date

# %% [markdown]
# ##### Step 1: Prepare data and Create Analytical Base Table

# %%
dbutils.notebook.run("./PVO_101_DS_ABT", 0, {'country': country})

# %% [markdown]
# ##### Step 2:  Modelling Phase

# %%
dbutils.notebook.run("./PVO_102_DS_MODELLING", 0, {'country': country,'env': env, 'model': model})

# %% [markdown]
# ##### Step 3: Post-Modelling Phase

# %%
dbutils.notebook.run("./PVO_103_DS_POSTMODELLING", 0, {'country': country,'env': env, 'model': model})
